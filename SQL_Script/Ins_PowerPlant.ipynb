# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
#Read Data Analyst CSV file 
csv_file = 'data/world-power-plants-list.csv'
data_analyst_df = pd.read_csv(csv_file)
data_analyst_df.head()

#Clean Data Analyst DataFrame
new_data_analyst_df = data_analyst_df[['PLANT_URL',
'PLANT_NAME',
'PLANT_COUNTRY',
'PLANT_STATE',
'PLANT_COUNTRY_ASSIGNED_IDENTIFICATION_NUMBER',
'PLANT_EFFICIENT_AND_IMPACT',
'PLANT_OVERALL_RATING',
'PLANT_GEO_ASSIGNED_ID_NUMBER',
'PLANT_CURRENCY',
'PLANT_LATITUDE',
'PLANT_LONGITUDE',
'PLANT_TYPE_OF_PLANT',
'PLANT_LOCATION',
'PLANT_FUEL_TYPE_SECONDARY',
'PLANT_TYPE_OF_OWNERSHIP',
'TYPE',
'TYPE_URL',
'geopoint']].copy()
new_data_analyst_df.dropna()
new_data_analyst_df.head()
# Out:
#                                            PLANT_URL  \
# 0  http://www.globalenergyobservatory.org/geoid/4...
# 1  http://www.globalenergyobservatory.org/geoid/4...
# 2  http://www.globalenergyobservatory.org/geoid/4...
# 3  http://www.globalenergyobservatory.org/geoid/4...
# 4  http://www.globalenergyobservatory.org/geoid/4...
#
#                                          PLANT_NAME PLANT_COUNTRY  \
# 0         Aschach Hydroelectric Power Plant Austria       Austria
# 1  Abwinden-Asten Hydroelectric Power Plant Austria       Austria
# 2         Vermunt Hydroelectric Power Plant Austria       Austria
# 3           Zongo Hydroelectric Power Plant Bolivia       Bolivia
# 4           Cahua Hydroelectric Power Plant Bolivia       Bolivia
#
#      PLANT_STATE PLANT_COUNTRY_ASSIGNED_IDENTIFICATION_NUMBER  \
# 0  Upper Austria                                          NaN
# 1  Upper Austria                                          NaN
# 2     Vorarlberg                                          NaN
# 3         La Paz                                          NaN
# 4         La Paz                                          NaN
#
#   PLANT_EFFICIENT_AND_IMPACT         PLANT_OVERALL_RATING  \
# 0                        NaN  Environmentally Responsible
# 1                        NaN  Environmentally Responsible
# 2                        NaN  Environmentally Responsible
# 3                        NaN  Environmentally Responsible
# 4                        NaN  Environmentally Responsible
#
#    PLANT_GEO_ASSIGNED_ID_NUMBER  PLANT_CURRENCY  PLANT_LATITUDE  \
# 0                       45057.0            45.0        48.38530
# 1                       45165.0            45.0        48.24798
# 2                       45209.0            45.0        46.96880
# 3                       44738.0            20.0       -16.27190
# 4                       44748.0            20.0       -16.04561
#
#    PLANT_LONGITUDE                    PLANT_TYPE_OF_PLANT  \
# 0          14.0230       Dam with run-of-river generation
# 1          14.4305   Barrage with run-of-river Generation
# 2          10.0558  Water discharged from another project
# 3         -68.1227            Dam on river with reservoir
# 4         -67.9939  Water discharged from another project
#
#                            PLANT_LOCATION PLANT_FUEL_TYPE_SECONDARY  \
# 0         Aschach, Upper Austria, Austria                       NaN
# 1  Abwinden-Asten, Upper Austria, Austria                       NaN
# 2           Partenen, Vorarlberg, Austria                       NaN
# 3          Huayna Potasi, La Paz, Bolivia                       NaN
# 4          Huayna Potasi, La Paz, Bolivia                       NaN
#
#   PLANT_TYPE_OF_OWNERSHIP   TYPE  \
# 0                     NaN  HYDRO
# 1                     NaN  HYDRO
# 2                     NaN  HYDRO
# 3                     NaN  HYDRO
# 4                     NaN  HYDRO
#
#                                             TYPE_URL             geopoint
# 0  http://www.globalenergyobservatory.org/list.ph...      48.3853, 14.023
# 1  http://www.globalenergyobservatory.org/list.ph...    48.24798, 14.4305
# 2  http://www.globalenergyobservatory.org/list.ph...     46.9688, 10.0558
# 3  http://www.globalenergyobservatory.org/list.ph...   -16.2719, -68.1227
# 4  http://www.globalenergyobservatory.org/list.ph...  -16.04561, -67.9939

# %%
from config import username, password

#Create Engine and connection to Database
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/World_power_plant')
connection = engine.connect()

#Verify tables
engine.table_names()
# Out:
# ['world_plant_list']

# %%
#Use pandas to load data analyst csv into converted DataFrame into database
new_data_analyst_df.to_sql(name='world_plant_list', con=engine, if_exists='replace', index=False)
